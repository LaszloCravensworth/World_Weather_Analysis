# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 728

# %%
# Import the requests library.
import requests
import time
from datetime import datetime
# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_weather_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"Date": city_date,
                          "City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_description,
                          })

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 1 | villa sandino
# Processing Record 4 of Set 1 | cape town
# Processing Record 5 of Set 1 | busselton
# Processing Record 6 of Set 1 | ribeira grande
# Processing Record 7 of Set 1 | erdenet
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | saint-philippe
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | melbourne
# Processing Record 12 of Set 1 | coquimbo
# Processing Record 13 of Set 1 | saskylakh
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | bredasdorp
# Processing Record 16 of Set 1 | severo-kurilsk
# Processing Record 17 of Set 1 | lorengau
# Processing Record 18 of Set 1 | parrita
# Processing Record 19 of Set 1 | avarua
# Processing Record 20 of Set 1 | bambanglipuro
# Processing Record 21 of Set 1 | sedam
# Processing Record 22 of Set 1 | victoria
# Processing Record 23 of Set 1 | bethel
# Processing Record 24 of Set 1 | borovskoy
# Processing Record 25 of Set 1 | ancud
# Processing Record 26 of Set 1 | ningyang
# Processing Record 27 of Set 1 | lakes entrance
# Processing Record 28 of Set 1 | cherskiy
# Processing Record 29 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 30 of Set 1 | waipawa
# Processing Record 31 of Set 1 | flin flon
# Processing Record 32 of Set 1 | adre
# Processing Record 33 of Set 1 | samarai
# Processing Record 34 of Set 1 | ushuaia
# Processing Record 35 of Set 1 | yelkhovka
# Processing Record 36 of Set 1 | keffi
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | iqaluit
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | carnarvon
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | arraial do cabo
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | simao
# Processing Record 45 of Set 1 | dapaong
# Processing Record 46 of Set 1 | barrow
# Processing Record 47 of Set 1 | atuona
# Processing Record 48 of Set 1 | torbay
# Processing Record 49 of Set 1 | soe
# Processing Record 50 of Set 1 | butaritari
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | bambous virieux
# Processing Record 3 of Set 2 | castro
# Processing Record 4 of Set 2 | alofi
# Processing Record 5 of Set 2 | yining
# Processing Record 6 of Set 2 | mocorito
# Processing Record 7 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 8 of Set 2 | kisangani
# Processing Record 9 of Set 2 | pervoye maya
# Processing Record 10 of Set 2 | mar del plata
# Processing Record 11 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 2 | biak
# Processing Record 13 of Set 2 | broome
# Processing Record 14 of Set 2 | rikitea
# Processing Record 15 of Set 2 | novikovo
# Processing Record 16 of Set 2 | qaanaaq
# Processing Record 17 of Set 2 | sao mateus
# Processing Record 18 of Set 2 | tomatlan
# Processing Record 19 of Set 2 | hunza
# City not found. Skipping...
# Processing Record 20 of Set 2 | east london
# Processing Record 21 of Set 2 | bandarbeyla
# Processing Record 22 of Set 2 | puerto ayora
# Processing Record 23 of Set 2 | karratha
# Processing Record 24 of Set 2 | port elizabeth
# Processing Record 25 of Set 2 | el espinal
# Processing Record 26 of Set 2 | novyye burasy
# Processing Record 27 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 | strezhevoy
# Processing Record 29 of Set 2 | college
# Processing Record 30 of Set 2 | shangrao
# Processing Record 31 of Set 2 | sedkyrkeshch
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | pacific grove
# Processing Record 34 of Set 2 | nome
# Processing Record 35 of Set 2 | guayaramerin
# Processing Record 36 of Set 2 | hamilton
# Processing Record 37 of Set 2 | bluff
# Processing Record 38 of Set 2 | khatanga
# Processing Record 39 of Set 2 | boende
# Processing Record 40 of Set 2 | mizdah
# Processing Record 41 of Set 2 | hilo
# Processing Record 42 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | cidreira
# Processing Record 45 of Set 2 | port blair
# Processing Record 46 of Set 2 | kutum
# Processing Record 47 of Set 2 | rongcheng
# Processing Record 48 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 2 | jamestown
# Processing Record 50 of Set 2 | pochutla
# Processing Record 1 of Set 3 | longyearbyen
# Processing Record 2 of Set 3 | necochea
# Processing Record 3 of Set 3 | cardinal
# Processing Record 4 of Set 3 | general teran
# Processing Record 5 of Set 3 | puerto escondido
# Processing Record 6 of Set 3 | norman wells
# Processing Record 7 of Set 3 | luderitz
# Processing Record 8 of Set 3 | ponta do sol
# Processing Record 9 of Set 3 | guinabsan
# Processing Record 10 of Set 3 | marsa matruh
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | srednekolymsk
# Processing Record 13 of Set 3 | constitucion
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | isfara
# Processing Record 16 of Set 3 | tura
# Processing Record 17 of Set 3 | portland
# Processing Record 18 of Set 3 | ilulissat
# Processing Record 19 of Set 3 | moussoro
# Processing Record 20 of Set 3 | aksarka
# Processing Record 21 of Set 3 | churapcha
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | kiunga
# Processing Record 24 of Set 3 | ewa beach
# Processing Record 25 of Set 3 | walvis bay
# Processing Record 26 of Set 3 | souillac
# Processing Record 27 of Set 3 | swan river
# Processing Record 28 of Set 3 | northam
# Processing Record 29 of Set 3 | moerai
# Processing Record 30 of Set 3 | carauari
# Processing Record 31 of Set 3 | pinillos
# Processing Record 32 of Set 3 | hasaki
# Processing Record 33 of Set 3 | kaeo
# Processing Record 34 of Set 3 | oda
# Processing Record 35 of Set 3 | sao joao da barra
# Processing Record 36 of Set 3 | boden
# Processing Record 37 of Set 3 | betanzos
# Processing Record 38 of Set 3 | sukhobuzimskoye
# Processing Record 39 of Set 3 | thompson
# Processing Record 40 of Set 3 | kollo
# Processing Record 41 of Set 3 | tasiilaq
# Processing Record 42 of Set 3 | ostersund
# Processing Record 43 of Set 3 | la sarre
# Processing Record 44 of Set 3 | shumskiy
# Processing Record 45 of Set 3 | aykhal
# Processing Record 46 of Set 3 | cap-aux-meules
# Processing Record 47 of Set 3 | jackson
# Processing Record 48 of Set 3 | egvekinot
# Processing Record 49 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 3 | nara
# Processing Record 1 of Set 4 | san quintin
# Processing Record 2 of Set 4 | hermanus
# Processing Record 3 of Set 4 | quatre cocos
# Processing Record 4 of Set 4 | nikolskoye
# Processing Record 5 of Set 4 | sisimiut
# Processing Record 6 of Set 4 | surskoye
# Processing Record 7 of Set 4 | saint george
# Processing Record 8 of Set 4 | ipubi
# Processing Record 9 of Set 4 | port lincoln
# Processing Record 10 of Set 4 | katherine
# Processing Record 11 of Set 4 | barinas
# Processing Record 12 of Set 4 | leningradskiy
# Processing Record 13 of Set 4 | pangnirtung
# Processing Record 14 of Set 4 | kartaly
# Processing Record 15 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 4 | kelamangalam
# Processing Record 17 of Set 4 | cabo san lucas
# Processing Record 18 of Set 4 | smithers
# Processing Record 19 of Set 4 | giyani
# Processing Record 20 of Set 4 | colborne
# Processing Record 21 of Set 4 | kapaa
# Processing Record 22 of Set 4 | husavik
# Processing Record 23 of Set 4 | komsomolskiy
# Processing Record 24 of Set 4 | kodiak
# Processing Record 25 of Set 4 | dingle
# Processing Record 26 of Set 4 | saldanha
# Processing Record 27 of Set 4 | lenauheim
# Processing Record 28 of Set 4 | havre-saint-pierre
# Processing Record 29 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 4 | asfi
# Processing Record 31 of Set 4 | borogontsy
# Processing Record 32 of Set 4 | chhindwara
# Processing Record 33 of Set 4 | rocha
# Processing Record 34 of Set 4 | ndele
# Processing Record 35 of Set 4 | jabiru
# City not found. Skipping...
# Processing Record 36 of Set 4 | sinnamary
# Processing Record 37 of Set 4 | bubaque
# Processing Record 38 of Set 4 | lucea
# Processing Record 39 of Set 4 | georgetown
# Processing Record 40 of Set 4 | estreito
# Processing Record 41 of Set 4 | ola
# Processing Record 42 of Set 4 | carolina
# Processing Record 43 of Set 4 | sioux lookout
# Processing Record 44 of Set 4 | pandan
# Processing Record 45 of Set 4 | havelock
# Processing Record 46 of Set 4 | bukachacha
# Processing Record 47 of Set 4 | itoman
# Processing Record 48 of Set 4 | antsohihy
# Processing Record 49 of Set 4 | sao filipe
# Processing Record 50 of Set 4 | kangaatsiaq
# Processing Record 1 of Set 5 | urumqi
# Processing Record 2 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 3 of Set 5 | nantucket
# Processing Record 4 of Set 5 | narsaq
# Processing Record 5 of Set 5 | acapulco
# Processing Record 6 of Set 5 | roald
# Processing Record 7 of Set 5 | gravdal
# Processing Record 8 of Set 5 | moville
# Processing Record 9 of Set 5 | salalah
# Processing Record 10 of Set 5 | ulladulla
# Processing Record 11 of Set 5 | trois-rivieres
# Processing Record 12 of Set 5 | marzuq
# Processing Record 13 of Set 5 | dezful
# Processing Record 14 of Set 5 | esmeralda
# Processing Record 15 of Set 5 | concepcion
# Processing Record 16 of Set 5 | mayo
# Processing Record 17 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 5 | mapiripan
# Processing Record 19 of Set 5 | kulhudhuffushi
# Processing Record 20 of Set 5 | rundu
# Processing Record 21 of Set 5 | berdigestyakh
# Processing Record 22 of Set 5 | puerto ayacucho
# Processing Record 23 of Set 5 | sterling
# Processing Record 24 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 25 of Set 5 | nouadhibou
# Processing Record 26 of Set 5 | abong mbang
# Processing Record 27 of Set 5 | manaure
# Processing Record 28 of Set 5 | cayenne
# Processing Record 29 of Set 5 | krasnoselkup
# Processing Record 30 of Set 5 | labuhan
# Processing Record 31 of Set 5 | nagato
# Processing Record 32 of Set 5 | clyde river
# Processing Record 33 of Set 5 | katsuura
# Processing Record 34 of Set 5 | tame
# Processing Record 35 of Set 5 | kimbe
# Processing Record 36 of Set 5 | eyl
# Processing Record 37 of Set 5 | kaspiyskiy
# Processing Record 38 of Set 5 | yarkovo
# Processing Record 39 of Set 5 | nouakchott
# Processing Record 40 of Set 5 | yellowknife
# Processing Record 41 of Set 5 | ilo
# Processing Record 42 of Set 5 | chokurdakh
# Processing Record 43 of Set 5 | kanniyakumari
# Processing Record 44 of Set 5 | geraldton
# Processing Record 45 of Set 5 | laguna
# Processing Record 46 of Set 5 | lagoa
# Processing Record 47 of Set 5 | lebu
# Processing Record 48 of Set 5 | maun
# Processing Record 49 of Set 5 | klaksvik
# Processing Record 50 of Set 5 | shitkino
# Processing Record 1 of Set 6 | pisco
# Processing Record 2 of Set 6 | porto novo
# Processing Record 3 of Set 6 | jiayuguan
# Processing Record 4 of Set 6 | hohhot
# Processing Record 5 of Set 6 | oriximina
# Processing Record 6 of Set 6 | udachnyy
# Processing Record 7 of Set 6 | marystown
# Processing Record 8 of Set 6 | takoradi
# Processing Record 9 of Set 6 | chuy
# Processing Record 10 of Set 6 | yulara
# Processing Record 11 of Set 6 | kloulklubed
# Processing Record 12 of Set 6 | tual
# Processing Record 13 of Set 6 | faanui
# Processing Record 14 of Set 6 | zhigansk
# Processing Record 15 of Set 6 | talnakh
# Processing Record 16 of Set 6 | saint-francois
# Processing Record 17 of Set 6 | la orilla
# Processing Record 18 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 19 of Set 6 | takhtamygda
# Processing Record 20 of Set 6 | margate
# Processing Record 21 of Set 6 | lensk
# Processing Record 22 of Set 6 | hithadhoo
# Processing Record 23 of Set 6 | la union
# Processing Record 24 of Set 6 | markova
# Processing Record 25 of Set 6 | awbari
# Processing Record 26 of Set 6 | tuim
# Processing Record 27 of Set 6 | sur
# Processing Record 28 of Set 6 | fortuna
# Processing Record 29 of Set 6 | talavera
# Processing Record 30 of Set 6 | kruisfontein
# Processing Record 31 of Set 6 | tuatapere
# Processing Record 32 of Set 6 | shimoda
# Processing Record 33 of Set 6 | pevek
# Processing Record 34 of Set 6 | treuchtlingen
# Processing Record 35 of Set 6 | sorland
# Processing Record 36 of Set 6 | grindavik
# Processing Record 37 of Set 6 | srandakan
# Processing Record 38 of Set 6 | byron bay
# Processing Record 39 of Set 6 | seoul
# Processing Record 40 of Set 6 | erenhot
# Processing Record 41 of Set 6 | san juan
# Processing Record 42 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 43 of Set 6 | kamaishi
# Processing Record 44 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 6 | vizinga
# Processing Record 46 of Set 6 | popondetta
# Processing Record 47 of Set 6 | manokwari
# Processing Record 48 of Set 6 | lovozero
# Processing Record 49 of Set 6 | beatrice
# Processing Record 50 of Set 6 | taraz
# Processing Record 1 of Set 7 | peace river
# Processing Record 2 of Set 7 | mount gambier
# Processing Record 3 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 4 of Set 7 | merauke
# Processing Record 5 of Set 7 | altona
# Processing Record 6 of Set 7 | dossor
# Processing Record 7 of Set 7 | nokaneng
# Processing Record 8 of Set 7 | suez
# Processing Record 9 of Set 7 | tasbuget
# City not found. Skipping...
# Processing Record 10 of Set 7 | togur
# Processing Record 11 of Set 7 | bathsheba
# Processing Record 12 of Set 7 | coahuayana
# Processing Record 13 of Set 7 | dabakala
# Processing Record 14 of Set 7 | mabaruma
# Processing Record 15 of Set 7 | peschanokopskoye
# Processing Record 16 of Set 7 | healdsburg
# Processing Record 17 of Set 7 | lavrentiya
# Processing Record 18 of Set 7 | shieli
# Processing Record 19 of Set 7 | lozovik
# Processing Record 20 of Set 7 | ust-karsk
# Processing Record 21 of Set 7 | etah
# Processing Record 22 of Set 7 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 7 | tiarei
# Processing Record 24 of Set 7 | pouebo
# Processing Record 25 of Set 7 | florence
# Processing Record 26 of Set 7 | beloha
# Processing Record 27 of Set 7 | port hardy
# Processing Record 28 of Set 7 | san cristobal
# Processing Record 29 of Set 7 | vila franca do campo
# Processing Record 30 of Set 7 | kondopoga
# Processing Record 31 of Set 7 | cap malheureux
# Processing Record 32 of Set 7 | poum
# Processing Record 33 of Set 7 | novospasskoye
# Processing Record 34 of Set 7 | vilyuysk
# Processing Record 35 of Set 7 | muli
# Processing Record 36 of Set 7 | esperance
# Processing Record 37 of Set 7 | balikpapan
# Processing Record 38 of Set 7 | long beach
# Processing Record 39 of Set 7 | kichera
# Processing Record 40 of Set 7 | faya
# Processing Record 41 of Set 7 | gladstone
# Processing Record 42 of Set 7 | tocopilla
# Processing Record 43 of Set 7 | fare
# Processing Record 44 of Set 7 | vila
# Processing Record 45 of Set 7 | encruzilhada
# Processing Record 46 of Set 7 | lompoc
# Processing Record 47 of Set 7 | sri aman
# Processing Record 48 of Set 7 | poronaysk
# Processing Record 49 of Set 7 | iwanai
# Processing Record 50 of Set 7 | norrtalje
# Processing Record 1 of Set 8 | kumano
# Processing Record 2 of Set 8 | tidore
# City not found. Skipping...
# Processing Record 3 of Set 8 | haines junction
# Processing Record 4 of Set 8 | manacor
# Processing Record 5 of Set 8 | turukhansk
# Processing Record 6 of Set 8 | daru
# Processing Record 7 of Set 8 | liaocheng
# Processing Record 8 of Set 8 | mahanoro
# Processing Record 9 of Set 8 | linping
# Processing Record 10 of Set 8 | atbasar
# Processing Record 11 of Set 8 | oktyabrskiy
# Processing Record 12 of Set 8 | chapais
# Processing Record 13 of Set 8 | lasa
# Processing Record 14 of Set 8 | kralendijk
# Processing Record 15 of Set 8 | qabis
# City not found. Skipping...
# Processing Record 16 of Set 8 | la ronge
# Processing Record 17 of Set 8 | balagansk
# Processing Record 18 of Set 8 | taloqan
# Processing Record 19 of Set 8 | levokumskoye
# Processing Record 20 of Set 8 | ende
# Processing Record 21 of Set 8 | lumeje
# Processing Record 22 of Set 8 | elban
# Processing Record 23 of Set 8 | kavieng
# Processing Record 24 of Set 8 | shiraz
# Processing Record 25 of Set 8 | chernyshevskiy
# Processing Record 26 of Set 8 | makakilo city
# Processing Record 27 of Set 8 | ouahigouya
# Processing Record 28 of Set 8 | ixtapa
# Processing Record 29 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 8 | palmer
# Processing Record 31 of Set 8 | storforshei
# Processing Record 32 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 33 of Set 8 | provideniya
# Processing Record 34 of Set 8 | stornoway
# Processing Record 35 of Set 8 | uchiza
# Processing Record 36 of Set 8 | mahebourg
# Processing Record 37 of Set 8 | guerrero negro
# Processing Record 38 of Set 8 | svetlyy
# Processing Record 39 of Set 8 | zeya
# Processing Record 40 of Set 8 | lieksa
# Processing Record 41 of Set 8 | bombay
# Processing Record 42 of Set 8 | vilhena
# Processing Record 43 of Set 8 | kamenka
# Processing Record 44 of Set 8 | valjevo
# Processing Record 45 of Set 8 | pitimbu
# Processing Record 46 of Set 8 | clonakilty
# Processing Record 47 of Set 8 | koulamoutou
# Processing Record 48 of Set 8 | sivas
# Processing Record 49 of Set 8 | edd
# Processing Record 50 of Set 8 | bereda
# Processing Record 1 of Set 9 | kaya
# Processing Record 2 of Set 9 | koungou
# Processing Record 3 of Set 9 | sungairaya
# Processing Record 4 of Set 9 | buala
# Processing Record 5 of Set 9 | linqiong
# Processing Record 6 of Set 9 | wanlaweyn
# Processing Record 7 of Set 9 | anjangaon
# Processing Record 8 of Set 9 | lexington
# Processing Record 9 of Set 9 | aklavik
# Processing Record 10 of Set 9 | palmas
# Processing Record 11 of Set 9 | dwarka
# Processing Record 12 of Set 9 | vardo
# Processing Record 13 of Set 9 | iberia
# Processing Record 14 of Set 9 | waingapu
# Processing Record 15 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 9 | lopandino
# Processing Record 17 of Set 9 | karlskrona
# Processing Record 18 of Set 9 | ahipara
# Processing Record 19 of Set 9 | arona
# Processing Record 20 of Set 9 | namatanai
# Processing Record 21 of Set 9 | adil-yangiyurt
# Processing Record 22 of Set 9 | hobyo
# Processing Record 23 of Set 9 | aguimes
# Processing Record 24 of Set 9 | falun
# Processing Record 25 of Set 9 | nelson bay
# Processing Record 26 of Set 9 | shingu
# Processing Record 27 of Set 9 | vestmanna
# Processing Record 28 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 9 | hovd
# Processing Record 30 of Set 9 | forestville
# Processing Record 31 of Set 9 | nicoya
# Processing Record 32 of Set 9 | capreol
# Processing Record 33 of Set 9 | ondjiva
# Processing Record 34 of Set 9 | gandorhun
# Processing Record 35 of Set 9 | kupang
# Processing Record 36 of Set 9 | padang
# Processing Record 37 of Set 9 | luna
# Processing Record 38 of Set 9 | kismayo
# Processing Record 39 of Set 9 | humaita
# Processing Record 40 of Set 9 | locri
# Processing Record 41 of Set 9 | sechura
# Processing Record 42 of Set 9 | sigli
# Processing Record 43 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 9 | kjollefjord
# Processing Record 45 of Set 9 | angul
# Processing Record 46 of Set 9 | atar
# Processing Record 47 of Set 9 | rawlins
# Processing Record 48 of Set 9 | richmond hill
# Processing Record 49 of Set 9 | tigil
# Processing Record 50 of Set 9 | boone
# Processing Record 1 of Set 10 | bundaberg
# Processing Record 2 of Set 10 | rassvet
# Processing Record 3 of Set 10 | balkhash
# Processing Record 4 of Set 10 | belmonte
# Processing Record 5 of Set 10 | port hedland
# Processing Record 6 of Set 10 | ahar
# Processing Record 7 of Set 10 | red wing
# Processing Record 8 of Set 10 | sola
# Processing Record 9 of Set 10 | flinders
# Processing Record 10 of Set 10 | saint simons
# Processing Record 11 of Set 10 | tshikapa
# Processing Record 12 of Set 10 | soyo
# Processing Record 13 of Set 10 | beira
# Processing Record 14 of Set 10 | carai
# Processing Record 15 of Set 10 | aksarayskiy
# Processing Record 16 of Set 10 | tulagi
# Processing Record 17 of Set 10 | ballina
# Processing Record 18 of Set 10 | luganville
# Processing Record 19 of Set 10 | nezhinka
# Processing Record 20 of Set 10 | solnechnyy
# Processing Record 21 of Set 10 | bilibino
# Processing Record 22 of Set 10 | hollola
# Processing Record 23 of Set 10 | cauquenes
# Processing Record 24 of Set 10 | touros
# Processing Record 25 of Set 10 | jalu
# Processing Record 26 of Set 10 | binzhou
# Processing Record 27 of Set 10 | port-gentil
# Processing Record 28 of Set 10 | lata
# Processing Record 29 of Set 10 | vila velha
# Processing Record 30 of Set 10 | bassar
# Processing Record 31 of Set 10 | sabang
# Processing Record 32 of Set 10 | tanout
# Processing Record 33 of Set 10 | colon
# Processing Record 34 of Set 10 | toamasina
# Processing Record 35 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 36 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 37 of Set 10 | xining
# Processing Record 38 of Set 10 | kolimvari
# City not found. Skipping...
# Processing Record 39 of Set 10 | erdaojiang
# Processing Record 40 of Set 10 | darab
# Processing Record 41 of Set 10 | codrington
# Processing Record 42 of Set 10 | santa maria
# Processing Record 43 of Set 10 | sydney
# Processing Record 44 of Set 10 | nalut
# Processing Record 45 of Set 10 | tervel
# Processing Record 46 of Set 10 | phnum penh
# City not found. Skipping...
# Processing Record 47 of Set 10 | saint-paul
# Processing Record 48 of Set 10 | catabola
# Processing Record 49 of Set 10 | meulaboh
# Processing Record 50 of Set 10 | ust-kulom
# Processing Record 1 of Set 11 | anahuac
# Processing Record 2 of Set 11 | grand gaube
# Processing Record 3 of Set 11 | kandi
# Processing Record 4 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 11 | janakpur
# Processing Record 6 of Set 11 | caravelas
# Processing Record 7 of Set 11 | riyadh
# Processing Record 8 of Set 11 | umm kaddadah
# Processing Record 9 of Set 11 | saint-georges
# Processing Record 10 of Set 11 | omboue
# Processing Record 11 of Set 11 | coihaique
# Processing Record 12 of Set 11 | raga
# Processing Record 13 of Set 11 | kahului
# Processing Record 14 of Set 11 | la cruz
# Processing Record 15 of Set 11 | kanye
# Processing Record 16 of Set 11 | rio grande
# Processing Record 17 of Set 11 | yelniki
# Processing Record 18 of Set 11 | kent
# Processing Record 19 of Set 11 | camacari
# Processing Record 20 of Set 11 | calvia
# Processing Record 21 of Set 11 | voh
# Processing Record 22 of Set 11 | sungaipenuh
# Processing Record 23 of Set 11 | nemuro
# Processing Record 24 of Set 11 | kawalu
# Processing Record 25 of Set 11 | puerto el triunfo
# Processing Record 26 of Set 11 | obo
# Processing Record 27 of Set 11 | darovskoy
# Processing Record 28 of Set 11 | uarini
# Processing Record 29 of Set 11 | mwinilunga
# Processing Record 30 of Set 11 | mount isa
# Processing Record 31 of Set 11 | thinadhoo
# Processing Record 32 of Set 11 | yanan
# City not found. Skipping...
# Processing Record 33 of Set 11 | camacha
# Processing Record 34 of Set 11 | blama
# Processing Record 35 of Set 11 | felipe carrillo puerto
# Processing Record 36 of Set 11 | gbarnga
# Processing Record 37 of Set 11 | redlands
# Processing Record 38 of Set 11 | albion
# Processing Record 39 of Set 11 | kendal
# Processing Record 40 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 11 | tiksi
# Processing Record 42 of Set 11 | ostrovnoy
# Processing Record 43 of Set 11 | parainen
# Processing Record 44 of Set 11 | los llanos de aridane
# Processing Record 45 of Set 11 | bilma
# Processing Record 46 of Set 11 | cheuskiny
# City not found. Skipping...
# Processing Record 47 of Set 11 | sept-iles
# Processing Record 48 of Set 11 | gazojak
# Processing Record 49 of Set 11 | russell
# Processing Record 50 of Set 11 | gua musang
# Processing Record 1 of Set 12 | port macquarie
# Processing Record 2 of Set 12 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 12 | kiama
# Processing Record 4 of Set 12 | centralia
# Processing Record 5 of Set 12 | baykit
# Processing Record 6 of Set 12 | pithoragarh
# Processing Record 7 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 8 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 9 of Set 12 | vaitape
# Processing Record 10 of Set 12 | hami
# Processing Record 11 of Set 12 | nuuk
# Processing Record 12 of Set 12 | pagudpud
# Processing Record 13 of Set 12 | kalevala
# Processing Record 14 of Set 12 | yar-sale
# Processing Record 15 of Set 12 | asmara
# Processing Record 16 of Set 12 | klokkarvik
# City not found. Skipping...
# Processing Record 17 of Set 12 | molteno
# Processing Record 18 of Set 12 | nioro
# Processing Record 19 of Set 12 | gorzow wielkopolski
# Processing Record 20 of Set 12 | boa vista
# Processing Record 21 of Set 12 | kempen
# Processing Record 22 of Set 12 | yemtsa
# Processing Record 23 of Set 12 | sambava
# Processing Record 24 of Set 12 | siquijor
# Processing Record 25 of Set 12 | havoysund
# Processing Record 26 of Set 12 | komatipoort
# Processing Record 27 of Set 12 | tautira
# Processing Record 28 of Set 12 | yumen
# Processing Record 29 of Set 12 | kaitangata
# Processing Record 30 of Set 12 | coyah
# Processing Record 31 of Set 12 | palu
# Processing Record 32 of Set 12 | saint-pierre
# Processing Record 33 of Set 12 | brigantine
# Processing Record 34 of Set 12 | quelimane
# Processing Record 35 of Set 12 | saint-augustin
# Processing Record 36 of Set 12 | satitoa
# City not found. Skipping...
# Processing Record 37 of Set 12 | whitehorse
# Processing Record 38 of Set 12 | half moon bay
# Processing Record 39 of Set 12 | worland
# Processing Record 40 of Set 12 | key largo
# Processing Record 41 of Set 12 | yuzhno-kurilsk
# Processing Record 42 of Set 12 | toguchin
# Processing Record 43 of Set 12 | baghdad
# Processing Record 44 of Set 12 | kodinsk
# Processing Record 45 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 46 of Set 12 | amambai
# Processing Record 47 of Set 12 | yeppoon
# Processing Record 48 of Set 12 | santa cruz de la palma
# Processing Record 49 of Set 12 | kalabo
# Processing Record 50 of Set 12 | tirat karmel
# Processing Record 1 of Set 13 | alekseyevka
# Processing Record 2 of Set 13 | hervey bay
# Processing Record 3 of Set 13 | sao joao do paraiso
# Processing Record 4 of Set 13 | alyangula
# Processing Record 5 of Set 13 | bose
# Processing Record 6 of Set 13 | laramie
# Processing Record 7 of Set 13 | saint-leu
# Processing Record 8 of Set 13 | okhotsk
# Processing Record 9 of Set 13 | valdivia
# Processing Record 10 of Set 13 | olinda
# Processing Record 11 of Set 13 | hofn
# Processing Record 12 of Set 13 | camiri
# Processing Record 13 of Set 13 | samana
# Processing Record 14 of Set 13 | bonthe
# Processing Record 15 of Set 13 | iquitos
# Processing Record 16 of Set 13 | diapaga
# Processing Record 17 of Set 13 | hualmay
# Processing Record 18 of Set 13 | yichun
# Processing Record 19 of Set 13 | anshun
# Processing Record 20 of Set 13 | kuryk
# Processing Record 21 of Set 13 | sao domingos
# Processing Record 22 of Set 13 | laiwu
# Processing Record 23 of Set 13 | paamiut
# Processing Record 24 of Set 13 | tuy hoa
# Processing Record 25 of Set 13 | vanimo
# Processing Record 26 of Set 13 | floro
# Processing Record 27 of Set 13 | batagay-alyta
# Processing Record 28 of Set 13 | varghis
# Processing Record 29 of Set 13 | khandagayty
# Processing Record 30 of Set 13 | radhanpur
# Processing Record 31 of Set 13 | kamien pomorski
# Processing Record 32 of Set 13 | fort nelson
# Processing Record 33 of Set 13 | kieta
# Processing Record 34 of Set 13 | alice town
# Processing Record 35 of Set 13 | maracas
# Processing Record 36 of Set 13 | dukat
# Processing Record 37 of Set 13 | kropotkin
# Processing Record 38 of Set 13 | roros
# Processing Record 39 of Set 13 | panzhihua
# Processing Record 40 of Set 13 | tracy
# Processing Record 41 of Set 13 | yarim
# Processing Record 42 of Set 13 | ciawi
# Processing Record 43 of Set 13 | oyem
# Processing Record 44 of Set 13 | traunstein
# Processing Record 45 of Set 13 | tamiahua
# Processing Record 46 of Set 13 | san luis
# Processing Record 47 of Set 13 | waddan
# Processing Record 48 of Set 13 | jalingo
# Processing Record 49 of Set 13 | zamhlay
# City not found. Skipping...
# Processing Record 50 of Set 13 | elat
# Processing Record 1 of Set 14 | antalaha
# Processing Record 2 of Set 14 | sao raimundo nonato
# Processing Record 3 of Set 14 | pemba
# Processing Record 4 of Set 14 | isangel
# Processing Record 5 of Set 14 | nishihara
# Processing Record 6 of Set 14 | barcelos
# Processing Record 7 of Set 14 | ituni
# City not found. Skipping...
# Processing Record 8 of Set 14 | rio gallegos
# Processing Record 9 of Set 14 | gat
# Processing Record 10 of Set 14 | caraballeda
# Processing Record 11 of Set 14 | coffs harbour
# Processing Record 12 of Set 14 | emmett
# Processing Record 13 of Set 14 | jishou
# Processing Record 14 of Set 14 | baldone
# Processing Record 15 of Set 14 | minsk
# Processing Record 16 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 17 of Set 14 | ilebo
# Processing Record 18 of Set 14 | kandalaksha
# Processing Record 19 of Set 14 | hendrina
# Processing Record 20 of Set 14 | shively
# Processing Record 21 of Set 14 | juazeirinho
# Processing Record 22 of Set 14 | lujan
# Processing Record 23 of Set 14 | roma
# Processing Record 24 of Set 14 | zyryanka
# Processing Record 25 of Set 14 | noumea
# Processing Record 26 of Set 14 | nichinan
# Processing Record 27 of Set 14 | juiz de fora
# Processing Record 28 of Set 14 | esfarayen
# Processing Record 29 of Set 14 | cowra
# Processing Record 30 of Set 14 | pundaguitan
# Processing Record 31 of Set 14 | jimma
# Processing Record 32 of Set 14 | molodizhne
# Processing Record 33 of Set 14 | baker city
# Processing Record 34 of Set 14 | jaciara
# Processing Record 35 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 36 of Set 14 | tecoanapa
# Processing Record 37 of Set 14 | batemans bay
# Processing Record 38 of Set 14 | naryan-mar
# Processing Record 39 of Set 14 | qasigiannguit
# Processing Record 40 of Set 14 | genhe
# Processing Record 41 of Set 14 | brae
# Processing Record 42 of Set 14 | beyneu
# Processing Record 43 of Set 14 | charlestown
# Processing Record 44 of Set 14 | ucluelet
# Processing Record 45 of Set 14 | yangambi
# Processing Record 46 of Set 14 | rawson
# Processing Record 47 of Set 14 | vestmannaeyjar
# Processing Record 48 of Set 14 | tena
# Processing Record 49 of Set 14 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 14 | limon
# Processing Record 1 of Set 15 | kasongo-lunda
# Processing Record 2 of Set 15 | rockland
# Processing Record 3 of Set 15 | stephenville crossing
# Processing Record 4 of Set 15 | shelburne
# Processing Record 5 of Set 15 | birao
# Processing Record 6 of Set 15 | beisfjord
# Processing Record 7 of Set 15 | tombouctou
# Processing Record 8 of Set 15 | yeniseysk
# Processing Record 9 of Set 15 | bolshaya vishera
# City not found. Skipping...
# Processing Record 10 of Set 15 | mala
# Processing Record 11 of Set 15 | matamoros
# Processing Record 12 of Set 15 | hirado
# Processing Record 13 of Set 15 | voznesenye
# Processing Record 14 of Set 15 | saint anthony
# Processing Record 15 of Set 15 | atambua
# Processing Record 16 of Set 15 | kargasok
# Processing Record 17 of Set 15 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 18 of Set 15 | pimentel
# Processing Record 19 of Set 15 | a
# City not found. Skipping...
# Processing Record 20 of Set 15 | rumoi
# Processing Record 21 of Set 15 | ombessa
# Processing Record 22 of Set 15 | west bay
# Processing Record 23 of Set 15 | brenham
# Processing Record 24 of Set 15 | bairiki
# Processing Record 25 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 26 of Set 15 | ledyard
# Processing Record 27 of Set 15 | evensk
# Processing Record 28 of Set 15 | aljezur
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 677

# %%
#Create city data df
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#                     Date            City Country      Lat       Lng  Max Temp  \
# 0    2022-02-10 02:30:10         Mataura      NZ -46.1927  168.8643     75.47
# 1    2022-02-10 02:30:11   Villa Sandino      NI  12.0483  -84.9936     68.59
# 2    2022-02-10 02:27:20       Cape Town      ZA -33.9258   18.4232     68.88
# 3    2022-02-10 02:30:12       Busselton      AU -33.6500  115.3333     83.05
# 4    2022-02-10 02:30:12  Ribeira Grande      PT  38.5167  -28.7000     59.14
# ..                   ...             ...     ...      ...       ...       ...
# 672  2022-02-10 02:49:08         Brenham      US  30.1669  -96.3977     57.04
# 673  2022-02-10 02:49:08         Bairiki      KI   1.3292  172.9752     86.00
# 674  2022-02-10 02:49:09         Ledyard      US  41.4398  -72.0142     36.10
# 675  2022-02-10 02:49:09          Evensk      RU  61.9500  159.2333     -5.19
# 676  2022-02-10 02:49:10         Aljezur      PT  37.3191   -8.8033     51.93
#
#      Humidity  Cloudiness  Wind Speed Current Description
# 0          29          16        8.25          few clouds
# 1          89           8        8.12           clear sky
# 2          89          75        5.75       broken clouds
# 3          36           5        3.02           clear sky
# 4          70           1       12.91           clear sky
# ..        ...         ...         ...                 ...
# 672        47           0        0.00           clear sky
# 673        74          40       10.36    scattered clouds
# 674        90           0        0.00           clear sky
# 675        77          80        1.10       broken clouds
# 676        73          94        4.27     overcast clouds
#
# [677 rows x 10 columns]

# %%
# Export DataFrame as CSV file
export_data_file = "WeatherPy_Database.csv"
city_data_df.to_csv(export_data_file, index_label="City_ID")
